# %%
API_KEYS = [
    "",
    "",
    "",
]

# %%
# -------------------- CONFIG --------------------

CSV_PATH = "destination_activities_generalised.csv"  # your CSV with: location, activity_1..activity_5

TOP_N_ACTIVITIES        = None   # None = all activity columns; or set e.g. 3
TARGET_REVIEWS_PER_QUERY = 100   # stop early once we reach this many reviews
MAX_REVIEWS_PER_QUERY    = 200   # hard cap per query

PAGE_SIZE               = 20     # max allowed by API v1
NEXT_PAGE_DELAY_SEC     = 2.0    # short pause before using nextPageToken
REQUESTS_PER_SECOND     = 2.0    # throttle all HTTP calls
DETAILS_SLEEP_SEC       = 0.15   # tiny pause between details
MAX_RETRIES             = 4

# -------------------- IMPORTS --------------------
import time, json, math, random, requests
import pandas as pd
from typing import List, Dict, Any, Optional, Tuple

# -------------------- BUILD QUERIES --------------------
def build_dict_from_csv(csv_path: str, top_n: Optional[int]) -> Dict[str, List[str]]:
    df = pd.read_csv(csv_path)
    cols = list(df.columns)
    if len(cols) < 6:
        raise ValueError("CSV must have at least 6 columns: location + 5 activities.")
    location_col = cols[0]
    activity_cols = [c for c in cols if c.lower().startswith("activity_")] or cols[1:6]

    acts_by_loc: Dict[str, List[str]] = {}
    for _, row in df.iterrows():
        loc = str(row[location_col]).strip()
        acts = []
        for c in activity_cols:
            v = row.get(c, None)
            if pd.notna(v):
                s = str(v).strip()
                if s: acts.append(s)
        if top_n is not None:
            acts = acts[:top_n]
        acts_by_loc[loc] = acts
    return acts_by_loc

def build_queries_from_dict(acts_by_loc: Dict[str, List[str]]) -> List[str]:
    return [f"{a} in {loc}" for loc, acts in acts_by_loc.items() for a in acts]

# -------------------- KEY ROTATION & THROTTLE --------------------
class KeyRotator:
    def __init__(self, keys: List[str]):
        if not keys: raise ValueError("Provide at least one API key.")
        self.keys = keys
        self.i = 0
    def next(self) -> str:
        k = self.keys[self.i]
        self.i = (self.i + 1) % len(self.keys)
        return k

rotator = KeyRotator(API_KEYS)
_last_request_ts = 0.0

def _throttle():
    global _last_request_ts
    interval = 1.0 / max(0.1, REQUESTS_PER_SECOND)
    now = time.time()
    sleep_for = max(0.0, _last_request_ts + interval - now)
    if sleep_for: time.sleep(sleep_for)
    _last_request_ts = time.time()

# -------------------- API v1 CALLS (your working pattern) --------------------
SEARCH_URL  = "https://places.googleapis.com/v1/places:searchText"
DETAILS_URL = "https://places.googleapis.com/v1/places/{place_id}"

def _post_json(url: str, headers: Dict[str,str], json_body: Dict[str,Any]) -> Dict[str,Any]:
    # basic retry/backoff on 429 / 5xx
    delay = 1.0
    for attempt in range(1, MAX_RETRIES+1):
        _throttle()
        r = requests.post(url, headers=headers, json=json_body, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 500, 502, 503, 504):
            time.sleep(delay); delay = min(delay*2, 20)
            continue
        # surface errors
        try:
            msg = r.json()
        except Exception:
            msg = r.text
        raise RuntimeError(f"POST {url} failed ({r.status_code}): {msg}")
    # last try
    _throttle()
    r = requests.post(url, headers=headers, json=json_body, timeout=30)
    try:
        return r.json()
    except Exception:
        raise RuntimeError(f"POST {url} failed after retries: {r.status_code}")

def _get_json(url: str, headers: Dict[str,str]) -> Dict[str,Any]:
    delay = 1.0
    for attempt in range(1, MAX_RETRIES+1):
        _throttle()
        r = requests.get(url, headers=headers, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 500, 502, 503, 504):
            time.sleep(delay); delay = min(delay*2, 20)
            continue
        try:
            msg = r.json()
        except Exception:
            msg = r.text
        raise RuntimeError(f"GET {url} failed ({r.status_code}): {msg}")
    _throttle()
    r = requests.get(url, headers=headers, timeout=30)
    try:
        return r.json()
    except Exception:
        raise RuntimeError(f"GET {url} failed after retries: {r.status_code}")

def places_search_text_v1(query: str, key: str, page_token: Optional[str] = None) -> Dict[str,Any]:
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": key,
        # Include nextPageToken in mask (as you did)
        "X-Goog-FieldMask": "places.id,places.displayName,places.formattedAddress,nextPageToken",
    }
    body = {
        "textQuery": query,
        "pageSize": PAGE_SIZE
    }
    if page_token:
        body["pageToken"] = page_token
    return _post_json(SEARCH_URL, headers, body)

def place_details_v1(place_id: str, key: str) -> Dict[str,Any]:
    """
    Places API (New) details request with an explicit field mask for review subfields.
    """
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": key,
        # Ask only for what we need – include nested review fields explicitly
        "X-Goog-FieldMask": (
            "id,displayName,formattedAddress,rating,userRatingCount,"
            "reviews.rating,"
            "reviews.text,"                       # {text, languageCode}
            "reviews.originalText,"               # {text, languageCode}
            "reviews.authorAttribution.displayName,"
            "reviews.publishTime,"
            "reviews.relativePublishTimeDescription"
        ),
    }
    url = DETAILS_URL.format(place_id=place_id)
    return _get_json(url, headers)

# -------------------- RESUMABLE IN-MEMORY STATE --------------------
def init_state_new(queries: List[str], prev_state: Optional[Dict[str,Any]] = None) -> Dict[str,Any]:
    state = prev_state.copy() if prev_state else {"queries": {}, "completed": []}
    for q in queries:
        if q not in state["queries"]:
            state["queries"][q] = {
                "nextPageToken": None,
                "places_done": {},          # place_id -> True
                "reviews_collected": 0,
                "done": False
            }
    return state

# -------------------- ONE QUERY (one page per pass) --------------------
def run_one_query_new(query: str, state: Dict[str,Any], verbose: bool = True) -> List[Dict[str,Any]]:
    q = state["queries"][query]
    rows: List[Dict[str,Any]] = []

    if q["done"] or q["reviews_collected"] >= MAX_REVIEWS_PER_QUERY:
        q["done"] = True
        if query not in state["completed"]: state["completed"].append(query)
        if verbose: print(f"[{query}] already done (collected={q['reviews_collected']}).")
        return rows

    if q["nextPageToken"]:
        time.sleep(NEXT_PAGE_DELAY_SEC)

    resp = places_search_text_v1(query, rotator.next(), page_token=q["nextPageToken"])
    places = resp.get("places", []) or []
    q["nextPageToken"] = resp.get("nextPageToken")

    if verbose:
        print(f"[{query}] places={len(places)}, nextPageToken={bool(q['nextPageToken'])}")

    # optional priority: most-rated first (if userRatingCount present)
    places.sort(key=lambda p: p.get("userRatingCount", 0), reverse=True)

    for p in places:
        if q["reviews_collected"] >= MAX_REVIEWS_PER_QUERY:
            q["done"] = True
            if query not in state["completed"]: state["completed"].append(query)
            break

        pid = p.get("id")
        if not pid or q["places_done"].get(pid):
            continue

        det = place_details_v1(pid, rotator.next())
        reviews = det.get("reviews", []) or []

        name = (det.get("displayName") or {}).get("text", p.get("displayName", {}).get("text",""))
        addr = det.get("formattedAddress", p.get("formattedAddress",""))
        rating = det.get("rating")
        count  = det.get("userRatingCount")

        remain = MAX_REVIEWS_PER_QUERY - q["reviews_collected"]
        to_take = reviews[:remain]

        for r in to_take:
            # --- SAFE extraction for text + language ---
            txt_obj = r.get("text")
            if isinstance(txt_obj, dict):
                review_text = (txt_obj.get("text") or "")
                lang_from_text = txt_obj.get("languageCode")
            else:
                review_text = (txt_obj or "")
                lang_from_text = None

            orig_obj = r.get("originalText")
            lang_from_orig = None
            if isinstance(orig_obj, dict):
                lang_from_orig = orig_obj.get("languageCode")
                # if you prefer original text over translated:
                if not review_text:
                    review_text = (orig_obj.get("text") or "")

            review_language = lang_from_text or lang_from_orig

            # Normalize text (only if it's a string)
            if isinstance(review_text, str):
                review_text = review_text.replace("\n", " ").strip()

            # split "activity in location"
            activity, location = None, None
            if " in " in query:
                parts = query.rsplit(" in ", 1)
                activity, location = parts[0], parts[1]


            rows.append({
                "query": query,
                "activity": activity,
                "location": location,
                "place_id": pid,
                "place_name": name,
                "formatted_address": addr,
                "rating": rating,
                "user_ratings_total": count,
                "review_author_name": ((r.get("authorAttribution") or {}).get("displayName")),
                "review_rating": r.get("rating"),
                "review_relative_time": r.get("relativePublishTimeDescription"),
                "review_text": review_text,
                "review_language": review_language,
                "publishTime": r.get("publishTime"),
            })

        q["reviews_collected"] += len(to_take)
        q["places_done"][pid] = True

        time.sleep(DETAILS_SLEEP_SEC)

        if q["reviews_collected"] >= TARGET_REVIEWS_PER_QUERY:
            q["done"] = True
            if query not in state["completed"]: state["completed"].append(query)
            break

    if not q["nextPageToken"]:
        q["done"] = True
        if query not in state["completed"]: state["completed"].append(query)

    if verbose and not rows:
        print(f"[{query}] no reviews appended this pass.")
    return rows

# -------------------- BATCH RUNNER --------------------
def run_all_queries_new(
    prev_state: Optional[Dict[str,Any]] = None,
    max_queries_per_run: Optional[int] = 50
) -> Tuple[pd.DataFrame, Dict[str,Any]]:
    acts_by_loc = build_dict_from_csv(CSV_PATH, TOP_N_ACTIVITIES)
    queries = build_queries_from_dict(acts_by_loc)
    state = init_state_new(queries, prev_state)

    pending = [q for q in queries if not state["queries"][q]["done"]]
    if max_queries_per_run is not None:
        pending = pending[:max_queries_per_run]

    new_rows: List[Dict[str,Any]] = []
    for idx, q in enumerate(pending, 1):
        print(f"[{idx}/{len(pending)}] {q}")
        new_rows.extend(run_one_query_new(q, state, verbose=True))

    df_batch = pd.DataFrame(new_rows, columns=[
        "query","activity","location",
        "place_id","place_name","formatted_address",
        "rating","user_ratings_total","review_author_name","review_rating",
        "review_relative_time","review_text","review_language","publishTime"
    ])

    return df_batch, state

#-------------- PROGRESS ----------------------

def summarize_progress(state: dict, target: int = 100) -> pd.DataFrame:
    """
    Build a DataFrame showing progress for every query in `state`.
    Assumes query format: "<activity> in <location>".
    """
    rows = []
    qmap = state.get("queries", {})
    for q, s in qmap.items():
        # try to split "activity in location" (robust to accidental extra " in ")
        activity, location = None, None
        if " in " in q:
            parts = q.rsplit(" in ", 1)
            activity = parts[0]
            location = parts[1]
        rows.append({
            "query": q,
            "location": location,
            "activity": activity,
            "reviews_collected": s.get("reviews_collected", 0),
            "done": bool(s.get("done", False)),
            "has_next_page": bool(s.get("nextPageToken")),
            "places_processed": len(s.get("places_done", {})),
            "remaining_to_target": max(0, target - int(s.get("reviews_collected", 0))),
        })
    df = pd.DataFrame(rows).sort_values(
        ["done", "remaining_to_target", "reviews_collected"],
        ascending=[True, True, False]
    ).reset_index(drop=True)

    return df

# %%
df_batch, state = run_all_queries_new(prev_state=None, max_queries_per_run=50)
df_batch.head()
# Out:
# [1/50] immersive experience in London
# [immersive experience in London] places=20, nextPageToken=True
# [2/50] theatre in London
# [theatre in London] places=20, nextPageToken=True
# [3/50] boat cruise in London
# [boat cruise in London] places=20, nextPageToken=True
# [4/50] museum in London
# [museum in London] places=20, nextPageToken=True
# [5/50] market in London
# [market in London] places=20, nextPageToken=True
# [6/50] boat cruise in Paris
# [boat cruise in Paris] places=20, nextPageToken=True
# [7/50] landmark in Paris
# [landmark in Paris] places=20, nextPageToken=True
# [8/50] museum in Paris
# [museum in Paris] places=20, nextPageToken=True
# [9/50] neighborhood in Paris
# [neighborhood in Paris] places=2, nextPageToken=False
# [neighborhood in Paris] no reviews appended this pass.
# [10/50] park/garden in Paris
# [park/garden in Paris] places=20, nextPageToken=True
# [11/50] architecture in Barcelona
# [architecture in Barcelona] places=20, nextPageToken=True
# [12/50] water sport in Barcelona
# [water sport in Barcelona] places=20, nextPageToken=True
# [13/50] adventure sport in Barcelona
# [adventure sport in Barcelona] places=20, nextPageToken=True
# [14/50] sports venue in Barcelona
# [sports venue in Barcelona] places=16, nextPageToken=False
# [15/50] museum in Barcelona
# [museum in Barcelona] places=20, nextPageToken=True
# [16/50] museum in Rome
# [museum in Rome] places=20, nextPageToken=True
# [17/50] historic site in Rome
# [historic site in Rome] places=20, nextPageToken=True
# [18/50] historic site in Rome
# [historic site in Rome] already done (collected=100).
# [19/50] historic site in Rome
# [historic site in Rome] already done (collected=100).
# [20/50] park/garden in Rome
# [park/garden in Rome] places=20, nextPageToken=True
# [21/50] historic square in Venice
# [historic square in Venice] places=7, nextPageToken=False
# [22/50] boat ride in Venice
# [boat ride in Venice] places=20, nextPageToken=True
# [23/50] island visit in Venice
# [island visit in Venice] places=20, nextPageToken=True
# [24/50] boat ride in Venice
# [boat ride in Venice] places=16, nextPageToken=True
# [25/50] shop in Venice
# [shop in Venice] places=20, nextPageToken=True
# [26/50] historic site in Athens
# [historic site in Athens] places=20, nextPageToken=True
# [27/50] museum in Athens
# [museum in Athens] places=20, nextPageToken=True
# [28/50] market in Athens
# [market in Athens] places=20, nextPageToken=True
# [29/50] museum in Athens
# [museum in Athens] already done (collected=100).
# [30/50] viewpoint in Athens
# [viewpoint in Athens] places=10, nextPageToken=False
# [31/50] boat cruise in Amsterdam
# [boat cruise in Amsterdam] places=20, nextPageToken=True
# [32/50] museum in Amsterdam
# [museum in Amsterdam] places=20, nextPageToken=True
# [33/50] museum in Amsterdam
# [museum in Amsterdam] already done (collected=100).
# [34/50] park/garden in Amsterdam
# [park/garden in Amsterdam] places=20, nextPageToken=True
# [35/50] neighborhood in Amsterdam
# [neighborhood in Amsterdam] places=1, nextPageToken=False
# [neighborhood in Amsterdam] no reviews appended this pass.
# [36/50] zoo in Berlin
# [zoo in Berlin] places=2, nextPageToken=False
# [37/50] landmark in Berlin
# [landmark in Berlin] places=20, nextPageToken=True
# [38/50] landmark in Berlin
# [landmark in Berlin] already done (collected=100).
# [39/50] square in Berlin
# [square in Berlin] places=20, nextPageToken=True
# [40/50] market in Berlin
# [market in Berlin] places=20, nextPageToken=True
# [41/50] park/garden in Prague
# [park/garden in Prague] places=20, nextPageToken=True
# [42/50] landmark in Prague
# [landmark in Prague] places=20, nextPageToken=True
# [43/50] old town in Prague
# [old town in Prague] places=1, nextPageToken=False
# [old town in Prague] no reviews appended this pass.
# [44/50] river walk in Prague
# [river walk in Prague] places=20, nextPageToken=True
# [45/50] historic site in Prague
# [historic site in Prague] places=20, nextPageToken=True
# [46/50] music/performance in Vienna
# [music/performance in Vienna] places=20, nextPageToken=True
# [47/50] park/garden in Vienna
# [park/garden in Vienna] places=20, nextPageToken=True
# [48/50] amusement park in Vienna
# [amusement park in Vienna] places=1, nextPageToken=False
# [49/50] carriage ride in Vienna
# [carriage ride in Vienna] places=16, nextPageToken=False
# [50/50] cafe culture in Vienna
# [cafe culture in Vienna] places=20, nextPageToken=True
#                             query                     place_id  \
# 0  immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 1  immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 2  immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 3  immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 4  immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
#
#                                         place_name  \
# 0  The War of The Worlds: The Immersive Experience
# 1  The War of The Worlds: The Immersive Experience
# 2  The War of The Worlds: The Immersive Experience
# 3  The War of The Worlds: The Immersive Experience
# 4  The War of The Worlds: The Immersive Experience
#
#                        formatted_address  rating  user_ratings_total  \
# 0  56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 1  56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 2  56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 3  56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 4  56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
#
#           review_author_name  review_rating review_relative_time  \
# 0  paula-lou Salkeld (Pezzy)              4          3 weeks ago
# 1          Sarah Harleyquinn              5         4 months ago
# 2                Hannah Wild              5         4 months ago
# 3                Tim Oldland              5           a week ago
# 4              Velda Mazzara              5         5 months ago
#
#                                          review_text review_language  \
# 0  As massive war of the worlds fans we weren't s...              en
# 1  Having always liked War Of the Worlds my partn...              en
# 2  Wow, what a fun experience! I didn't know  any...              en
# 3  Absolutely fantastic experience! I’ve been a f...              en
# 4  The experience was really good, could not faul...              en
#
#                       publishTime
# 0  2025-08-04T12:00:55.142807609Z
# 1     2025-04-21T08:53:41.700071Z
# 2     2025-04-21T07:27:28.218635Z
# 3  2025-08-16T07:57:11.543664413Z
# 4     2025-03-19T09:53:41.343420Z

# %%
df_batch.head(20)
# Out:
#                              query                     place_id  \
# 0   immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 1   immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 2   immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 3   immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 4   immersive experience in London  ChIJW4IlshQDdkgR7CWekBzGqJI
# 5   immersive experience in London  ChIJW0sjYeEFdkgRdwCty-McgJs
# 6   immersive experience in London  ChIJW0sjYeEFdkgRdwCty-McgJs
# 7   immersive experience in London  ChIJW0sjYeEFdkgRdwCty-McgJs
# 8   immersive experience in London  ChIJW0sjYeEFdkgRdwCty-McgJs
# 9   immersive experience in London  ChIJW0sjYeEFdkgRdwCty-McgJs
# 10  immersive experience in London  ChIJId2oNroFdkgReafXXIrGnkY
# 11  immersive experience in London  ChIJId2oNroFdkgReafXXIrGnkY
# 12  immersive experience in London  ChIJId2oNroFdkgReafXXIrGnkY
# 13  immersive experience in London  ChIJId2oNroFdkgReafXXIrGnkY
# 14  immersive experience in London  ChIJId2oNroFdkgReafXXIrGnkY
# 15  immersive experience in London  ChIJIVvFX6UcdkgRTB2GO2PGxgk
# 16  immersive experience in London  ChIJIVvFX6UcdkgRTB2GO2PGxgk
# 17  immersive experience in London  ChIJIVvFX6UcdkgRTB2GO2PGxgk
# 18  immersive experience in London  ChIJIVvFX6UcdkgRTB2GO2PGxgk
# 19  immersive experience in London  ChIJIVvFX6UcdkgRTB2GO2PGxgk
#
#                                          place_name  \
# 0   The War of The Worlds: The Immersive Experience
# 1   The War of The Worlds: The Immersive Experience
# 2   The War of The Worlds: The Immersive Experience
# 3   The War of The Worlds: The Immersive Experience
# 4   The War of The Worlds: The Immersive Experience
# 5             Immersive Gamebox - Southbank, London
# 6             Immersive Gamebox - Southbank, London
# 7             Immersive Gamebox - Southbank, London
# 8             Immersive Gamebox - Southbank, London
# 9             Immersive Gamebox - Southbank, London
# 10               Frameless Immersive Art Experience
# 11               Frameless Immersive Art Experience
# 12               Frameless Immersive Art Experience
# 13               Frameless Immersive Art Experience
# 14               Frameless Immersive Art Experience
# 15                            Immersive Experiences
# 16                            Immersive Experiences
# 17                            Immersive Experiences
# 18                            Immersive Experiences
# 19                            Immersive Experiences
#
#                              formatted_address  rating  user_ratings_total  \
# 0        56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 1        56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 2        56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 3        56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 4        56 Leadenhall St, London EC3A 2BJ, UK     4.8                3088
# 5   Arch 3, 83 Scoresby St, London SE1 0XN, UK     4.9                4532
# 6   Arch 3, 83 Scoresby St, London SE1 0XN, UK     4.9                4532
# 7   Arch 3, 83 Scoresby St, London SE1 0XN, UK     4.9                4532
# 8   Arch 3, 83 Scoresby St, London SE1 0XN, UK     4.9                4532
# 9   Arch 3, 83 Scoresby St, London SE1 0XN, UK     4.9                4532
# 10           6 Marble Arch, London W1H 7AP, UK     4.6                4224
# 11           6 Marble Arch, London W1H 7AP, UK     4.6                4224
# 12           6 Marble Arch, London W1H 7AP, UK     4.6                4224
# 13           6 Marble Arch, London W1H 7AP, UK     4.6                4224
# 14           6 Marble Arch, London W1H 7AP, UK     4.6                4224
# 15          86-90 Paul St, London EC2A 4NE, UK     4.7                  45
# 16          86-90 Paul St, London EC2A 4NE, UK     4.7                  45
# 17          86-90 Paul St, London EC2A 4NE, UK     4.7                  45
# 18          86-90 Paul St, London EC2A 4NE, UK     4.7                  45
# [bamboo forest in Kyoto] places=1, nextPageToken=False
# [71/100] cultural activity in Kyoto
# [cultural activity in Kyoto] places=6, nextPageToken=False
# [72/100] food market in Kyoto
# [food market in Kyoto] places=1, nextPageToken=False
# [73/100] shrine/temple in Kyoto
# [shrine/temple in Kyoto] already done (collected=100).
# [74/100] palace in Seoul
# [palace in Seoul] places=20, nextPageToken=True
# [75/100] shopping in Seoul
# [shopping in Seoul] places=20, nextPageToken=True
# [76/100] historic village in Seoul
# [historic village in Seoul] places=15, nextPageToken=False
# [77/100] food market in Seoul
# [food market in Seoul] places=20, nextPageToken=True
# [78/100] river walk in Seoul
# [river walk in Seoul] places=6, nextPageToken=False
# [79/100] viewpoint in Hong Kong
# [viewpoint in Hong Kong] places=20, nextPageToken=True
# [80/100] market in Hong Kong
# [market in Hong Kong] places=20, nextPageToken=True
# [81/100] temple in Hong Kong
# [temple in Hong Kong] places=20, nextPageToken=True
# [82/100] theme park in Hong Kong
# [theme park in Hong Kong] places=20, nextPageToken=True
# [83/100] hiking in Hong Kong
# [hiking in Hong Kong] places=20, nextPageToken=True
# [84/100] park/garden in Singapore
# [park/garden in Singapore] places=20, nextPageToken=True
# [85/100] botanic garden in Singapore
# [botanic garden in Singapore] places=1, nextPageToken=False
# [86/100] viewpoint in Singapore
# [viewpoint in Singapore] places=20, nextPageToken=True
# [87/100] nature reserve in Singapore
# [nature reserve in Singapore] places=20, nextPageToken=True
# [88/100] resort in Singapore
# [resort in Singapore] places=20, nextPageToken=True
# [89/100] nightlife in Bangkok
# [nightlife in Bangkok] places=20, nextPageToken=True
# [90/100] market in Bangkok
# [market in Bangkok] places=20, nextPageToken=True
# [91/100] temple in Bangkok
# [temple in Bangkok] places=20, nextPageToken=True
# [92/100] street food in Bangkok
# [street food in Bangkok] places=20, nextPageToken=True
# [93/100] market in Bangkok
# [market in Bangkok] already done (collected=100).
# [94/100] old town in Hanoi
# [old town in Hanoi] places=1, nextPageToken=False
# [95/100] historic site in Hanoi
# [historic site in Hanoi] places=20, nextPageToken=True
# [96/100] theatre/show in Hanoi
# [theatre/show in Hanoi] places=19, nextPageToken=False
# [97/100] lake activity in Hanoi
# [lake activity in Hanoi] places=20, nextPageToken=True
# [98/100] historic village in Hanoi
# [historic village in Hanoi] places=20, nextPageToken=True
# [99/100] cooking class in Siem Reap
# [cooking class in Siem Reap] places=20, nextPageToken=True
# [100/100] temple in Siem Reap
# [temple in Siem Reap] places=20, nextPageToken=True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 df_batch2, state = run_all_queries_new(prev_state=state, max_queries_per_run=100)
# ----> 3 print_progress_summary(state, target=TARGET_REVIEWS_PER_QUERY)
#
# NameError: name 'print_progress_summary' is not defined

# %%
len(df_batch2)
# Out:
# 6291

# %%
df_batch3, state = run_all_queries_new(prev_state=state, max_queries_per_run=100)
# Out:
# [1/100] hiking in Interlaken
# [hiking in Interlaken] places=17, nextPageToken=False
# [2/100] workshop in Interlaken
# [workshop in Interlaken] places=3, nextPageToken=False
# [3/100] hiking in Lofoten Islands
# [hiking in Lofoten Islands] places=20, nextPageToken=True
# [77/100] adventure sport in Boracay
# [adventure sport in Boracay] places=20, nextPageToken=True
# [78/100] water sport in Boracay
# [water sport in Boracay] places=12, nextPageToken=False
# [79/100] sailing in Boracay
# [sailing in Boracay] places=14, nextPageToken=False
# [80/100] beach in Boracay
# [beach in Boracay] places=20, nextPageToken=True
# [81/100] market in Male
# [market in Male] places=13, nextPageToken=False
# [82/100] mosque in Male
# [mosque in Male] places=1, nextPageToken=False
# [mosque in Male] no reviews appended this pass.
# [83/100] boat cruise in Male
# [boat cruise in Male] places=1, nextPageToken=False
# [84/100] island hopping in Male
# [island hopping in Male] places=0, nextPageToken=False
# [island hopping in Male] no reviews appended this pass.
# [85/100] museum in Male
# [museum in Male] places=2, nextPageToken=False
# [86/100] memorial/museum in New York City
# [memorial/museum in New York City] places=1, nextPageToken=False
# [87/100] viewpoint in New York City
# [viewpoint in New York City] places=16, nextPageToken=False
# [88/100] park/garden in New York City
# [park/garden in New York City] places=20, nextPageToken=True
# [89/100] landmark in New York City
# [landmark in New York City] places=20, nextPageToken=True
# [90/100] landmark in New York City
# [landmark in New York City] already done (collected=100).
# [91/100] park/garden in San Francisco
# [park/garden in San Francisco] places=20, nextPageToken=True
# [92/100] aquarium in San Francisco
# [aquarium in San Francisco] places=11, nextPageToken=False
# [93/100] neighborhood in San Francisco
# [neighborhood in San Francisco] places=17, nextPageToken=False
# [94/100] surfing in San Francisco
# [surfing in San Francisco] places=20, nextPageToken=True
# [95/100] museum in San Francisco
# [museum in San Francisco] places=20, nextPageToken=True
# [96/100] beach in Miami
# [beach in Miami] places=1, nextPageToken=False
# [beach in Miami] no reviews appended this pass.
# [97/100] neighborhood in Miami
# [neighborhood in Miami] places=20, nextPageToken=True
# [98/100] aquarium/zoo in Miami
# [aquarium/zoo in Miami] places=16, nextPageToken=False
# [99/100] market in Miami
# [market in Miami] places=20, nextPageToken=True
# [100/100] safari/wildlife in Miami
# [safari/wildlife in Miami] places=12, nextPageToken=False

# %%
len(df_batch3)
# Out:
# 5234

# %%
df_batch4, state = run_all_queries_new(prev_state=state, max_queries_per_run=100)
# Out:
# [1/100] boat cruise in Raja Ampat
# [boat cruise in Raja Ampat] places=9, nextPageToken=False
# [2/100] hiking in Raja Ampat
# [hiking in Raja Ampat] places=20, nextPageToken=True
# [3/100] village visit in Raja Ampat
# [village visit in Raja Ampat] places=20, nextPageToken=True
# [4/100] boat cruise in Palawan
# [boat cruise in Palawan] places=20, nextPageToken=True
# [5/100] night activity in Palawan
# [night activity in Palawan] places=20, nextPageToken=True
# [6/100] boat cruise in Komodo Island
# [boat cruise in Komodo Island] places=3, nextPageToken=False
# [7/100] camping in Ladakh
# [camping in Ladakh] places=20, nextPageToken=True
# [8/100] temple in Bagan
# [temple in Bagan] places=20, nextPageToken=True
# [9/100] island hopping in Boracay
# [island hopping in Boracay] places=2, nextPageToken=False
# [10/100] adventure sport in Boracay
# [adventure sport in Boracay] places=5, nextPageToken=False
# [11/100] neighborhood in Miami
# [neighborhood in Miami] places=20, nextPageToken=True
# [adventure sport in Rio de Janeiro] places=20, nextPageToken=True
# [83/100] historic site in Cartagena
# [historic site in Cartagena] places=20, nextPageToken=True
# [84/100] water sport in Cartagena
# [water sport in Cartagena] places=11, nextPageToken=False
# [85/100] cooking class in Cartagena
# [cooking class in Cartagena] places=6, nextPageToken=False
# [86/100] castle/fort in Cartagena
# [castle/fort in Cartagena] places=1, nextPageToken=False
# [87/100] wellness/spa in Cartagena
# [wellness/spa in Cartagena] places=20, nextPageToken=True
# [88/100] cultural activity in Havana
# [cultural activity in Havana] places=20, nextPageToken=True
# [89/100] landmark in Havana
# [landmark in Havana] places=20, nextPageToken=True
# [90/100] museum in Havana
# [museum in Havana] places=20, nextPageToken=True
# [91/100] old town in Havana
# [old town in Havana] places=1, nextPageToken=False
# [92/100] theatre/show in Havana
# [theatre/show in Havana] places=6, nextPageToken=False
# [93/100] water sport in Cancún
# [water sport in Cancún] places=20, nextPageToken=True
# [94/100] historic site in Cancún
# [historic site in Cancún] places=20, nextPageToken=True
# [95/100] theme park in Cancún
# [theme park in Cancún] places=20, nextPageToken=True
# [96/100] theme park in Cancún
# [theme park in Cancún] places=18, nextPageToken=False
# [97/100] island visit in Cancún
# [island visit in Cancún] places=20, nextPageToken=True
# [98/100] boat ride in Tulum
# [boat ride in Tulum] places=20, nextPageToken=True
# [99/100] water sport in Tulum
# [water sport in Tulum] places=13, nextPageToken=False
# [100/100] adventure sport in Tulum
# [adventure sport in Tulum] places=5, nextPageToken=False

# %%
len(df_batch4)
# Out:
# 5692

# %%
df_batch4.head()
# Out:
#                        query                     place_id     place_name  \
# 0  boat cruise in Raja Ampat  ChIJaeiH1qb8Qi0RV_i5xC7DwM4  Misool Resort
# 1  boat cruise in Raja Ampat  ChIJaeiH1qb8Qi0RV_i5xC7DwM4  Misool Resort
# 2  boat cruise in Raja Ampat  ChIJaeiH1qb8Qi0RV_i5xC7DwM4  Misool Resort
# 3  boat cruise in Raja Ampat  ChIJaeiH1qb8Qi0RV_i5xC7DwM4  Misool Resort
# 4  boat cruise in Raja Ampat  ChIJaeiH1qb8Qi0RV_i5xC7DwM4  Misool Resort
#
#                                    formatted_address  rating  \
# 0  Yellu, South Misool, Raja Ampat Regency, West ...     4.8
# 1  Yellu, South Misool, Raja Ampat Regency, West ...     4.8
# 2  Yellu, South Misool, Raja Ampat Regency, West ...     4.8
# 3  Yellu, South Misool, Raja Ampat Regency, West ...     4.8
# 4  Yellu, South Misool, Raja Ampat Regency, West ...     4.8
#
#    user_ratings_total           review_author_name  review_rating  \
# 0                 111                          N T              5
# 1                 111                Sandra Rodner              5
# 2                 111                      Gintare              5
# 3                 111         mickisis1 (Bonnie S)              4
# 4                 111  Ken & Steve Timmons-Kinholt              5
#
#   review_relative_time                                        review_text  \
# 0          a month ago  This is a special place, and we decided to go ...
# 1        10 months ago  We visited Misool September 2024 and had an in...
# 2           a year ago  Just came back from spending a week in Misool ...
# 3           a year ago  I would have rated the rooms five stars if the...
# 4          2 years ago  I can't say enough good things about this plac...
#
#   review_language                     publishTime
# 0              en  2025-07-20T07:53:28.076436006Z
# 1              en     2024-10-06T19:20:53.449974Z
# 2              en     2024-04-13T06:36:11.936176Z
# 3              en     2023-11-29T12:27:35.173891Z
# 4              en     2023-03-12T14:14:50.823456Z

# %%
df_batch5, state = run_all_queries_new(prev_state=state, max_queries_per_run=100)
# Out:
# [1/100] bridge/walk in Vancouver
# [bridge/walk in Vancouver] places=6, nextPageToken=False
# [2/100] kayaking in Vancouver
# [kayaking in Vancouver] places=20, nextPageToken=True
# [3/100] wildlife safari in Alaska/Denali
# [wildlife safari in Alaska/Denali] places=2, nextPageToken=False
# [4/100] historic site in Honolulu/Oahu
# [historic site in Honolulu/Oahu] places=20, nextPageToken=True
# [5/100] adventure sport in Honolulu/Oahu
# [adventure sport in Honolulu/Oahu] places=20, nextPageToken=True
# [6/100] spa/wellness in Quebec City
# [spa/wellness in Quebec City] places=20, nextPageToken=True
# [7/100] adventure sport in Rio de Janeiro
# [adventure sport in Rio de Janeiro] places=20, nextPageToken=True
# [8/100] cultural activity in Havana
# [cultural activity in Havana] places=1, nextPageToken=False
# [9/100] museum in Havana
# [museum in Havana] places=20, nextPageToken=True
# [10/100] water sport in Cancún
# [water sport in Cancún] places=11, nextPageToken=False
# [11/100] historic site in Cancún
# [historic site in Cancún] places=20, nextPageToken=True
# [12/100] boat ride in Tulum
# [boat ride in Tulum] places=20, nextPageToken=True
# [13/100] historic site in Tulum
# [historic site in Tulum] places=20, nextPageToken=True
# [14/100] water sport in Punta Cana
# [water sport in Punta Cana] places=20, nextPageToken=True
# [15/100] adventure sport in Punta Cana
# [adventure sport in Punta Cana] places=20, nextPageToken=True
# [16/100] cultural activity in Punta Cana
# [cultural activity in Punta Cana] places=1, nextPageToken=False
# [17/100] adventure sport in Punta Cana
# [adventure sport in Punta Cana] places=20, nextPageToken=True
# [18/100] theme park in Punta Cana
# [theme park in Punta Cana] places=20, nextPageToken=True
# [19/100] water sport in Galápagos Islands
# [water sport in Galápagos Islands] places=20, nextPageToken=True
# [20/100] hiking in Galápagos Islands
# [hiking in Galápagos Islands] places=20, nextPageToken=True
# [21/100] diving/snorkel in Galápagos Islands
# [diving/snorkel in Galápagos Islands] places=20, nextPageToken=True
# [22/100] wildlife in Galápagos Islands
# [wildlife in Galápagos Islands] places=20, nextPageToken=True
# [23/100] water sport in Galápagos Islands
# [water sport in Galápagos Islands] already done (collected=100).
# [24/100] hiking in Torres del Paine
# [hiking in Torres del Paine] places=1, nextPageToken=False
# [25/100] water sport in Torres del Paine
# [water sport in Torres del Paine] places=1, nextPageToken=False
# [26/100] wildlife in Torres del Paine
# [wildlife in Torres del Paine] places=1, nextPageToken=False
# [27/100] horseback riding in Torres del Paine
# [horseback riding in Torres del Paine] places=20, nextPageToken=True
# [28/100] biking in Torres del Paine
# [biking in Torres del Paine] places=1, nextPageToken=False
# [29/100] stargazing in Atacama Desert
# [stargazing in Atacama Desert] places=1, nextPageToken=False
# [30/100] geothermal site in Atacama Desert
# [geothermal site in Atacama Desert] places=1, nextPageToken=False
# [31/100] hiking in Atacama Desert
# [old town in Marrakech] places=10, nextPageToken=False
# [67/100] spa/wellness in Marrakech
# [spa/wellness in Marrakech] places=20, nextPageToken=True
# [68/100] adventure sport in Marrakech
# [adventure sport in Marrakech] places=20, nextPageToken=True
# [69/100] historic site in Cairo
# [historic site in Cairo] places=20, nextPageToken=True
# [70/100] museum in Cairo
# [museum in Cairo] places=20, nextPageToken=True
# [71/100] boat cruise in Cairo
# [boat cruise in Cairo] places=20, nextPageToken=True
# [72/100] market in Cairo
# [market in Cairo] places=20, nextPageToken=True
# [73/100] park/garden in Cairo
# [park/garden in Cairo] places=20, nextPageToken=True
# [74/100] hiking in Cape Town
# [hiking in Cape Town] places=20, nextPageToken=True
# [75/100] hiking in Cape Town
# [hiking in Cape Town] already done (collected=100).
# [76/100] coastal walk in Cape Town
# [coastal walk in Cape Town] places=12, nextPageToken=False
# [77/100] day trip in Cape Town
# [day trip in Cape Town] places=20, nextPageToken=True
# [78/100] wildlife safari in Cape Town
# [wildlife safari in Cape Town] places=20, nextPageToken=True
# [79/100] wildlife safari in Kruger
# [wildlife safari in Kruger] places=5, nextPageToken=False
# [80/100] biking in Kruger
# [biking in Kruger] places=1, nextPageToken=False
# [81/100] cultural activity in Kruger
# [cultural activity in Kruger] places=1, nextPageToken=False
# [82/100] hot air balloon in Kruger
# [hot air balloon in Kruger] places=3, nextPageToken=False
# [83/100] wildlife safari in Kruger
# [wildlife safari in Kruger] already done (collected=24).
# [84/100] wildlife safari in Maasai Mara
# [wildlife safari in Maasai Mara] places=20, nextPageToken=True
# [85/100] cultural activity in Maasai Mara
# [cultural activity in Maasai Mara] places=1, nextPageToken=False
# [86/100] safari/wildlife in Maasai Mara
# [safari/wildlife in Maasai Mara] places=1, nextPageToken=False
# [87/100] birdwatching in Maasai Mara
# [birdwatching in Maasai Mara] places=9, nextPageToken=False
# [88/100] horseback riding in Maasai Mara
# [horseback riding in Maasai Mara] places=20, nextPageToken=True
# [89/100] wildlife safari in Serengeti
# [wildlife safari in Serengeti] places=20, nextPageToken=True
# [90/100] hot air balloon in Serengeti
# [hot air balloon in Serengeti] places=2, nextPageToken=False
# [91/100] wildlife safari in Serengeti
# [wildlife safari in Serengeti] places=20, nextPageToken=True
# [92/100] cultural visit in Serengeti
# [cultural visit in Serengeti] places=2, nextPageToken=False
# [93/100] hiking safari in Serengeti
# [hiking safari in Serengeti] places=20, nextPageToken=True
# [94/100] old town tour in Zanzibar
# [old town tour in Zanzibar] places=10, nextPageToken=False
# [95/100] snorkeling in Zanzibar
# [snorkeling in Zanzibar] places=12, nextPageToken=False
# [96/100] boat cruise in Zanzibar
# [boat cruise in Zanzibar] places=3, nextPageToken=False
# [97/100] forest walk in Zanzibar
# [forest walk in Zanzibar] places=12, nextPageToken=False
# [98/100] beach activity in Zanzibar
# [beach activity in Zanzibar] places=18, nextPageToken=False
# [99/100] trekking in Mount Kilimanjaro
# [trekking in Mount Kilimanjaro] places=10, nextPageToken=False
# [100/100] hot springs in Mount Kilimanjaro
# [hot springs in Mount Kilimanjaro] places=3, nextPageToken=False

# %%
len(df_batch5)
# Out:
# 5254

# %%
df_batch5.head()
# Out:
#                       query     activity   location  \
# 0  bridge/walk in Vancouver  bridge/walk  Vancouver
# 1  bridge/walk in Vancouver  bridge/walk  Vancouver
# 2  bridge/walk in Vancouver  bridge/walk  Vancouver
# 3  bridge/walk in Vancouver  bridge/walk  Vancouver
# 4  bridge/walk in Vancouver  bridge/walk  Vancouver
#
#                       place_id                         place_name  \
# 0  ChIJXeuJMwxuhlQRc-9kxg3cx0w  West Vancouver Centennial Seawalk
# 1  ChIJXeuJMwxuhlQRc-9kxg3cx0w  West Vancouver Centennial Seawalk
# 2  ChIJXeuJMwxuhlQRc-9kxg3cx0w  West Vancouver Centennial Seawalk
# 3  ChIJXeuJMwxuhlQRc-9kxg3cx0w  West Vancouver Centennial Seawalk
# 4  ChIJXeuJMwxuhlQRc-9kxg3cx0w  West Vancouver Centennial Seawalk
#
#                                    formatted_address  rating  \
# 0  2240 Bellevue Ave, West Vancouver, BC V7V 1C6,...     4.7
# 1  2240 Bellevue Ave, West Vancouver, BC V7V 1C6,...     4.7
# 2  2240 Bellevue Ave, West Vancouver, BC V7V 1C6,...     4.7
# 3  2240 Bellevue Ave, West Vancouver, BC V7V 1C6,...     4.7
# 4  2240 Bellevue Ave, West Vancouver, BC V7V 1C6,...     4.7
#
#    user_ratings_total   review_author_name  review_rating  \
# 0                 247             Harry Li              5
# 1                 247        Eddy Sarkisov              5
# 2                 247  Christian Johannsen              5
# 3                 247     James Concepcion              5
# 4                 247           Cara Black              5
#
#   review_relative_time                                        review_text  \
# 0           a year ago  I simply cannot find any word to describe this...
# 1        11 months ago  This is such a beautiful and spacious pathway ...
# 2           a year ago  Nice place to take a stroll along the ocean. P...
# 3          7 years ago  My favorite place to walk in the world. It is ...
# 4         2 months ago  Gorgeous view and places to sit! Highly recomm...
#
#   review_language                     publishTime
# 0              en     2024-06-09T02:56:58.261667Z
# 1              en     2024-09-27T05:57:59.363850Z
# 2              en     2024-05-01T14:58:31.586020Z
# 3              en        2018-06-06T01:31:49.509Z
# 4              en  2025-06-19T17:44:57.125456083Z

# %%
df_batch5.review_text.iloc[0]
# Out:
# 'I simply cannot find any word to describe this place. When you’re walking along the beach, you just couldn’t be upset, no matter what happened, you just feel so comfortable. Any random picture you take could be on the your home screen. The water temperature is OK to swim during the summer, there’s a lot of parking space at one end of the walk. You get to see the bridges Stanley Park, and always a lot of people boating, and big ships. Dogs are not permitted and so are bikes, but your dog could follow you just outside the fence if you trust them to do so. Nothing too special just a feeling of home.'

# %%
df_batch6, state = run_all_queries_new(prev_state=state, max_queries_per_run=100)
# Out:
# [1/100] historic site in Tulum
# [historic site in Tulum] places=20, nextPageToken=True
# [2/100] theme park in Punta Cana
# [theme park in Punta Cana] places=20, nextPageToken=True
# [3/100] hiking in Galápagos Islands
# [hiking in Galápagos Islands] places=20, nextPageToken=True
# [4/100] wildlife in Galápagos Islands
# [wildlife in Galápagos Islands] places=5, nextPageToken=False
# [5/100] horseback riding in Torres del Paine
# [horseback riding in Torres del Paine] places=2, nextPageToken=False
# [fishing in Musandam Fjords] places=20, nextPageToken=True
# [75/100] snorkeling in Muscat
# [snorkeling in Muscat] places=20, nextPageToken=True
# [76/100] mosque in Muscat
# [mosque in Muscat] places=20, nextPageToken=True
# [77/100] market in Muscat
# [market in Muscat] places=8, nextPageToken=False
# [78/100] natural site in Muscat
# [natural site in Muscat] places=20, nextPageToken=True
# [79/100] wildlife safari in Muscat
# [wildlife safari in Muscat] places=7, nextPageToken=False
# [80/100] architecture in Tel Aviv
# [architecture in Tel Aviv] places=20, nextPageToken=True
# [81/100] market in Tel Aviv
# [market in Tel Aviv] places=20, nextPageToken=True
# [82/100] old town tour in Tel Aviv
# [old town tour in Tel Aviv] places=18, nextPageToken=True
# [83/100] beach activity in Tel Aviv
# [beach activity in Tel Aviv] places=20, nextPageToken=True
# [84/100] street art in Tel Aviv
# [street art in Tel Aviv] places=2, nextPageToken=False
# [85/100] coastal walk in Sydney
# [coastal walk in Sydney] places=20, nextPageToken=True
# [86/100] zoo/aquarium in Sydney
# [zoo/aquarium in Sydney] places=6, nextPageToken=False
# [87/100] landmark in Sydney
# [landmark in Sydney] places=20, nextPageToken=True
# [88/100] historic site in Sydney
# [historic site in Sydney] places=20, nextPageToken=True
# [89/100] kayaking in Sydney
# [kayaking in Sydney] places=20, nextPageToken=True
# [90/100] adventure sport in Queenstown
# [adventure sport in Queenstown] places=20, nextPageToken=True
# [91/100] gondola ride in Queenstown
# [gondola ride in Queenstown] places=1, nextPageToken=False
# [92/100] adventure sport in Queenstown
# [adventure sport in Queenstown] already done (collected=100).
# [93/100] garden/park in Queenstown
# [garden/park in Queenstown] places=20, nextPageToken=True
# [94/100] biking in Queenstown
# [biking in Queenstown] places=20, nextPageToken=True
# [95/100] geothermal site in Rotorua
# [geothermal site in Rotorua] places=1, nextPageToken=False
# [96/100] treetop walk in Rotorua
# [treetop walk in Rotorua] places=1, nextPageToken=False
# [97/100] spa/wellness in Rotorua
# [spa/wellness in Rotorua] places=20, nextPageToken=True
# [98/100] gondola ride in Rotorua
# [gondola ride in Rotorua] places=1, nextPageToken=False
# [99/100] cultural activity in Rotorua
# [cultural activity in Rotorua] places=2, nextPageToken=False
# [100/100] snorkeling in Cairns
# [snorkeling in Cairns] places=20, nextPageToken=True

# %%
df_batch6, state = run_all_queries_new(prev_state=state, max_queries_per_run=50)
# Out:
# [1/21] boat cruise in Okavango Delta
# [boat cruise in Okavango Delta] places=19, nextPageToken=False
# [2/21] desert tour in Namib Desert
# [desert tour in Namib Desert] places=20, nextPageToken=True
# [3/21] snorkeling in Seychelles
# [snorkeling in Seychelles] places=20, nextPageToken=True
# [4/21] water sport in Mauritius
# [water sport in Mauritius] places=20, nextPageToken=True
# [5/21] village visit in Mauritius
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_batch6, state = run_all_queries_new(prev_state=state, max_queries_per_run=50)
#
# Cell In[25], line 295, in run_all_queries_new(prev_state, max_queries_per_run)
#     293 for idx, q in enumerate(pending, 1):
#     294     print(f"[{idx}/{len(pending)}] {q}")
# --> 295     new_rows.extend(run_one_query_new(q, state, verbose=True))
#     297 df_batch = pd.DataFrame(new_rows, columns=[
#     298     "query","activity","location",
#     299     "place_id","place_name","formatted_address",
#     300     "rating","user_ratings_total","review_author_name","review_rating",
#     301     "review_relative_time","review_text","review_language","publishTime"
#     302 ])
#     304 return df_batch, state
#
# Cell In[25], line 180, in run_one_query_new(query, state, verbose)
#     177     return rows
#     179 if q["nextPageToken"]:
# --> 180     time.sleep(NEXT_PAGE_DELAY_SEC)
#     182 resp = places_search_text_v1(query, rotator.next(), page_token=q["nextPageToken"])
#     183 places = resp.get("places", []) or []
#
# KeyboardInterrupt:

# %%
len(df_batch6)
# Out:
# 5676

# %%
df_batch6.head()
# Out:
#                     query       activity location  \
# 0  historic site in Tulum  historic site    Tulum
# 1  historic site in Tulum  historic site    Tulum
# 2  historic site in Tulum  historic site    Tulum
# 3  historic site in Tulum  historic site    Tulum
# 4  historic site in Tulum  historic site    Tulum
#
#                       place_id           place_name  \
# 0  ChIJgTQhxTMoUI8R6NkHj0toHsk  Laguna de Kaan Luum
# 1  ChIJgTQhxTMoUI8R6NkHj0toHsk  Laguna de Kaan Luum
# 2  ChIJgTQhxTMoUI8R6NkHj0toHsk  Laguna de Kaan Luum
# 3  ChIJgTQhxTMoUI8R6NkHj0toHsk  Laguna de Kaan Luum
# 4  ChIJgTQhxTMoUI8R6NkHj0toHsk  Laguna de Kaan Luum
#
#                    formatted_address  rating  user_ratings_total  \
# 0  77760 Tulum, Quintana Roo, Mexico     4.6                5419
# 1  77760 Tulum, Quintana Roo, Mexico     4.6                5419
# 2  77760 Tulum, Quintana Roo, Mexico     4.6                5419
# 3  77760 Tulum, Quintana Roo, Mexico     4.6                5419
# 4  77760 Tulum, Quintana Roo, Mexico     4.6                5419
#
#   review_author_name  review_rating review_relative_time  \
# 0         Luiz Balbo              5          2 weeks ago
# 1    David Castañeda              5          a month ago
# 2   Dalila Rodriguez              5          a month ago
# 3       Susana Simon              5         2 months ago
# 4        valeriia u.              4         3 months ago
#
#                                          review_text review_language  \
# 0  Absolutely stunning spot! Definitely a must-vi...              en
# 1  Laguna Kaan Luum is a stunning and peaceful la...              en
# 2  The lagoon is very kid-friendly—not deep at al...              en
# 3  Great place to spend the day. You can bring yo...              en
# 4  We arrived around 10 a.m. There were two of us...              en
#
#                       publishTime
# 0  2025-08-12T12:58:59.650866975Z
# 1  2025-07-16T20:15:39.022095397Z
# 2  2025-07-08T05:18:58.807980716Z
# 3  2025-06-16T20:22:54.228641423Z
# 4     2025-05-21T01:17:14.706070Z

# %%
df_batch7, state = run_all_queries_new(prev_state=state, max_queries_per_run=50)
# Out:
# [1/17] village visit in Mauritius
# [village visit in Mauritius] places=20, nextPageToken=True
# [2/17] historic site in Fes
# [historic site in Fes] places=20, nextPageToken=True
# [3/17] museum in Fes
# [museum in Fes] places=20, nextPageToken=True
# [4/17] landmark walk in Jerusalem
# [landmark walk in Jerusalem] places=15, nextPageToken=False
# [5/17] hiking in Petra
# [hiking in Petra] places=20, nextPageToken=True
# [6/17] landmark in Dubai
# [landmark in Dubai] places=20, nextPageToken=True
# [7/17] fishing in Musandam Fjords
# [fishing in Musandam Fjords] places=5, nextPageToken=False
# [8/17] snorkeling in Muscat
# [snorkeling in Muscat] places=20, nextPageToken=True
# [9/17] architecture in Tel Aviv
# [architecture in Tel Aviv] places=19, nextPageToken=True
# [10/17] old town tour in Tel Aviv
# [old town tour in Tel Aviv] places=17, nextPageToken=True
# [11/17] historic site in Sydney
# [historic site in Sydney] places=20, nextPageToken=True
# [12/17] biking in Queenstown
# [biking in Queenstown] places=16, nextPageToken=False
# [13/17] spa/wellness in Rotorua
# [spa/wellness in Rotorua] places=2, nextPageToken=False
# [14/17] rainforest tour in Cairns
# [rainforest tour in Cairns] places=20, nextPageToken=True
# [15/17] adventure sport in Cairns
# [adventure sport in Cairns] places=20, nextPageToken=True
# [16/17] coastal walk in Cairns
# [coastal walk in Cairns] places=13, nextPageToken=False
# [17/17] waterfall visit in Cairns
# [waterfall visit in Cairns] places=20, nextPageToken=True

# %%
df_batch6.tail()
# Out:
#                      query    activity location                     place_id  \
# 5671  snorkeling in Cairns  snorkeling   Cairns  ChIJZSkWhAJkeGkRfFLN5DqVsIw
# 5672  snorkeling in Cairns  snorkeling   Cairns  ChIJZSkWhAJkeGkRfFLN5DqVsIw
# 5673  snorkeling in Cairns  snorkeling   Cairns  ChIJZSkWhAJkeGkRfFLN5DqVsIw
# 5674  snorkeling in Cairns  snorkeling   Cairns  ChIJZSkWhAJkeGkRfFLN5DqVsIw
# 5675  snorkeling in Cairns  snorkeling   Cairns  ChIJZSkWhAJkeGkRfFLN5DqVsIw
#
#                                place_name  \
# 5671  Spirit of Freedom - Dive Liveaboard
# 5672  Spirit of Freedom - Dive Liveaboard
# 5673  Spirit of Freedom - Dive Liveaboard
# 5674  Spirit of Freedom - Dive Liveaboard
# 5675  Spirit of Freedom - Dive Liveaboard
#
#                                       formatted_address  rating  \
# 5671  319 Draper St, Parramatta Park QLD 4870, Austr...     4.8
# 5672  319 Draper St, Parramatta Park QLD 4870, Austr...     4.8
# 5673  319 Draper St, Parramatta Park QLD 4870, Austr...     4.8
# 5674  319 Draper St, Parramatta Park QLD 4870, Austr...     4.8
# 5675  319 Draper St, Parramatta Park QLD 4870, Austr...     4.8
#
#       user_ratings_total review_author_name  review_rating  \
# 5671                 104          Coco Tsai              5
# 5672                 104      Rob McJannett              5
# 5673                 104                F S              5
# 5674                 104      Sean Flaherty              5
# 5675                 104      Piotr Ślatała              5
#
#      review_relative_time                                        review_text  \
# 5671         5 months ago  Fantastic crew with amazing dives. First time ...
# 5672         6 months ago  Incredible Crew & Unforgettable Diving!  My 3-...
# 5673         6 months ago  The crew on the boat deserve 10 stars. I could...
# 5674         2 months ago  Unforgettable Dive Adventure – Spirit of Freed...
# 5675         7 months ago  Amazing experience. On the expensive side, but...
#
#      review_language                  publishTime
# 5671              en  2025-03-17T11:51:16.666192Z
# 5672              en  2025-02-28T00:41:58.962203Z
# 5673              en  2025-02-16T01:26:09.541078Z
# 5674              en  2025-06-01T12:48:31.585816Z
# 5675              en  2025-01-06T00:22:22.631196Z
