# %%
import requests
import pandas as pd

API_KEY = "your key
TOP_N = 3

# Step 1: Dictionary of locations with their top activities
activities_by_location = {
    "London": ["Live music", "Museums", "Historic landmarks", "Theatre", "Street food"],
    "Interlaken": ["Mountain hiking", "Skiing", "River rafting", "Wild swimming", "Paragliding"],
    "Kyoto": ["Shrines & Temples", "Traditional crafts", "Street food", "Gardens", "UNESCO heritage sites"],
    "Bali": ["Beach", "Jungle hiking", "Diving", "Volcano trekking", "Hot springs"],
    "Banff": ["National parks", "Mountain hiking", "Wildlife watching", "Canoeing", "Hot springs"],
    "Dubai": ["Modern architecture", "Desert safari", "Mosques", "Beach", "Shopping"],
    "Galápagos Islands": ["Wildlife watching", "Boat tours", "Snorkeling", "Island hopping", "Lagoon swimming"],
    "Rio de Janeiro": ["Beach", "Live music", "Street markets", "Historic landmarks", "Cable car"],
    "Petra": ["UNESCO heritage site", "Canyon hiking", "Archaeology", "Desert trekking", "Stargazing"],
    "Queenstown": ["Skiing", "Snowboarding", "Bungee jumping", "Wine tasting", "Lake cruises"]
}

# Step 2: Build queries like "beach in Bali"
queries = []
for location, activities in activities_by_location.items():
    for activity in activities:
        queries.append(f"{activity} in {location}")

print("Sample queries:", queries[:10])

# we want 5 reviews per 20 pois per activity per city
# Out:
# Sample queries: ['Live music in London', 'Museums in London', 'Historic landmarks in London', 'Theatre in London', 'Street food in London', 'Mountain hiking in Interlaken', 'Skiing in Interlaken', 'River rafting in Interlaken', 'Wild swimming in Interlaken', 'Paragliding in Interlaken']

# %%
all_reviews = []

search_url = "https://places.googleapis.com/v1/places:searchText"
details_url_template = "https://places.googleapis.com/v1/places/{place_id}"

search_headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "places.id,places.displayName,places.formattedAddress"
}

for query in queries:
    print(f"\n🔍 Searching: {query}")

    search_body = {"textQuery": query}
    search_response = requests.post(search_url, headers=search_headers, json=search_body).json()

    if "places" not in search_response:
        print(f"No places found for '{query}'")
        continue

    # Step 3: Take top N places
    places = search_response["places"][:TOP_N]

    for place in places:
        place_id = place["id"]
        place_name = place["displayName"]["text"]
        place_address = place.get("formattedAddress", "")

        print(f"Fetching reviews for {place_name} ({place_address})...")

        details_headers = {
            "Content-Type": "application/json",
            "X-Goog-Api-Key": API_KEY,
            "X-Goog-FieldMask": "id,displayName,reviews"
        }

        details_url = details_url_template.format(place_id=place_id)
        details_response = requests.get(details_url, headers=details_headers).json()

        reviews = details_response.get("reviews", [])
        for r in reviews:
            all_reviews.append({
                "query": query,
                "place_id": place_id,
                "place_name": place_name,
                "place_address": place_address,
                "rating": r.get("rating"),
                "text": r.get("text"),
                "author": r.get("authorAttribution", {}).get("displayName"),
                "publishTime": r.get("publishTime")
            })

# Step 4: Save results
df = pd.DataFrame(all_reviews)
print(df.head())
print(f"\n✅ Total reviews collected: {len(df)}")
# Out:
# 🔍 Searching: Live music in London
# Fetching reviews for Old Street Records (350, 356 Old St, London EC1V 9NQ, UK)...
# Fetching reviews for The Old Blue Last (38 Great Eastern St, London EC2A 3ES, UK)...
# Fetching reviews for Live Music Bar Soho - Blues and Jazz (Downstairs at the Spice, 6 Moor St, London W1D 5NA, UK)...
#
# 🔍 Searching: Museums in London
# Fetching reviews for The British Museum (Great Russell St, London WC1B 3DG, UK)...
# Fetching reviews for Natural History Museum (Cromwell Rd, South Kensington, London SW7 5BD, UK)...
# Fetching reviews for The National Gallery (Trafalgar Square, London WC2N 5DN, UK)...
#
# 🔍 Searching: Historic landmarks in London
# Fetching reviews for Tower of London (London EC3N 4AB, UK)...
# Fetching reviews for Apsley House (149 Piccadilly, London W1J 7NT, UK)...
# Fetching reviews for Monument to the Great Fire of London (Fish St Hill, London EC3R 8AH, UK)...
#
# 🔍 Searching: Theatre in London
# Fetching reviews for The Old Vic (103 The Cut, London SE1 8NB, UK)...
# Fetching reviews for Palace Theatre (113 Shaftesbury Ave, London W1D 5AY, UK)...
# Fetching reviews for Lyceum Theatre (21 Wellington St, London WC2E 7RQ, UK)...
#
# 🔍 Searching: Street food in London
# Fetching reviews for Tabard Street Food Market (215, 221 Borough High St, London SE1 1JA, UK)...
# Fetching reviews for Seven Dials Market (Earlham St, London WC2H 9LX, UK)...
# Fetching reviews for Mercato Metropolitano (42 Newington Causeway, London SE1 6DR, UK)...
#
# 🔍 Searching: Mountain hiking in Interlaken
# Fetching reviews for OUTDOOR - Interlaken Base (Industriestrasse 17, 3812 Wilderswil, Switzerland)...
# Fetching reviews for Sendli (Unnamed Road,3800, 3800 Interlaken, Switzerland)...
# Fetching reviews for Naturschutzgebiet Weissenau (Weissenaustrasse, 3800 Unterseen, Switzerland)...
#
# 🔍 Searching: Skiing in Interlaken
# Fetching reviews for OUTDOOR - Interlaken Base (Industriestrasse 17, 3812 Wilderswil, Switzerland)...
# Fetching reviews for Jungfrau Ski Region - Kleine Scheidegg - Männlichen - Wengen (Grundstrasse 54, 3818 Grindelwald, Switzerland)...
# Fetching reviews for Jungfrau Ski Region - Mürren - Schilthorn (3825 Lauterbrunnen, Switzerland)...
#
# 🔍 Searching: River rafting in Interlaken
# Fetching reviews for OUTDOOR - Interlaken Base (Industriestrasse 17, 3812 Wilderswil, Switzerland)...
# Fetching reviews for Rafting.ch (Interlaken CH, b, Hauptstrasse 38/e, 3800 Matten bei Interlaken, Switzerland)...
# Fetching reviews for Alpinraft (Hauptstrasse 36, 3800 Interlaken, Switzerland)...
#
# 🔍 Searching: Wild swimming in Interlaken
# Fetching reviews for The Beach (Lütschinenstrasse 24, 3806 Bönigen, Switzerland)...
# Fetching reviews for Neuhaus Swimming Steps (Seestrasse 119, 3800 Unterseen, Switzerland)...
# Fetching reviews for Badeplatz Niederried (3853 Niederried bei Interlaken, Switzerland)...
#
# 🔍 Searching: Paragliding in Interlaken
# Fetching reviews for Paragliding Interlaken GmbH (Höheweg 125, 3800 Interlaken, Switzerland)...
# Fetching reviews for AlpinAir Paragliding Interlaken (Untere Bönigstrasse 9, 3800 Interlaken, Switzerland)...
# Fetching reviews for Swiss Paragliding Interlaken (Centralstrasse 5, 3800 Interlaken, Switzerland)...
#
# 🔍 Searching: Shrines & Temples in Kyoto
# Fetching reviews for Fushimi Inari Taisha (68 Fukakusa Yabunouchichō, Fushimi Ward, Kyoto, 612-0882, Japan)...
#
# 🔍 Searching: Volcano trekking in Bali
# Fetching reviews for Bali Volcano Trek (Jl. Bukit Catu, Songan A, Kec. Kintamani, Kabupaten Bangli, Bali 80652, Indonesia)...
# Fetching reviews for Mount Batur Sunrise Trekking (Jl. Raya Gentong, Tegallalang, Kecamatan Ubud, Kabupaten Gianyar, Bali 80571, Indonesia)...
# Fetching reviews for Mount Abang (Abangsongan, Kintamani, Bangli Regency, Bali 80853, Indonesia)...
#
# 🔍 Searching: Hot springs in Bali
# Fetching reviews for Batur Natural Hot Spring (Toya Bungkah Kintamani Desa Pekraman Batur, Songan B, Kec. Kintamani, Kabupaten Bangli, Bali 80612, Indonesia)...
# Fetching reviews for Banjar Hot Spring (Jalan Banjar, Banjar, Kec. Banjar, Kabupaten Buleleng, Bali 81152, Indonesia)...
# Fetching reviews for Toya Devasya (Central Batur, Kintamani, Bangli Regency, Bali, Indonesia)...
#
# 🔍 Searching: National parks in Banff
# Fetching reviews for Banff National Park (Improvement District No. 9, AB T0L, Canada)...
#
# 🔍 Searching: Mountain hiking in Banff
# Fetching reviews for Banff National Park (Improvement District No. 9, AB T0L, Canada)...
# Fetching reviews for Sulphur Mountain Trail (Banff Upper Hot Springs, Improvement District No. 9, AB T0L, Canada)...
# Fetching reviews for Tunnel Mountain Trail (Improvement District No. 9, AB T1L 1H5, Canada)...
#
# 🔍 Searching: Wildlife watching in Banff
# Fetching reviews for Discover Banff Tours (215 Banff Ave, Banff, AB T1L 1C1, Canada)...
# Fetching reviews for Banff National Park (Improvement District No. 9, AB T0L, Canada)...
# Fetching reviews for Banff Wildlife Crossing (576P+F4C, Sawback, AB T1L 1J5, Canada)...
#
# 🔍 Searching: Canoeing in Banff
# Fetching reviews for Banff Canoe Club (Corner of Bow Ave and, Wolf St, Banff, AB T1L 1A8, Canada)...
#
# 🔍 Searching: Hot springs in Banff
# Fetching reviews for Banff Upper Hot Springs (1 Mountain Ave, Banff, AB T1L 1K2, Canada)...
#
# 🔍 Searching: Modern architecture in Dubai
# Fetching reviews for Al Mujassam (Near Dyna Trade - 16 A St Alfa Offices, Office N 30 - Dubai - ند الحمر - دبي - United Arab Emirates)...
# Fetching reviews for MEAN* Middle East Architecture Network (Office A105 Building 6 - Dubai Design District - Dubai - United Arab Emirates)...
# Fetching reviews for BMA Studio Architects (Office 5205, 2nd Floor, Building No.5, Gold & Diamond Park - شارع الشيخ زايد - القوز - منطقة القوز الصناعية 3 - دبي - United Arab Emirates)...
#
# 🔍 Searching: Desert safari in Dubai
# Fetching reviews for Desert Safari Tours Dubai (Room#409 A,4the floor,Al Firoshi Building,Salahuddin Road - Al Quoz - Al Quoz 4 - Dubai - United Arab Emirates)...
# Fetching reviews for Desert Safaris Dubai (Aspin Commercial Tower - Sheikh Zayed Rd - Trade Centre - Trade Centre 1 - Dubai - United Arab Emirates)...
# Fetching reviews for Safari Desert Dubai, UAE (Al Aweer - Al Belaida Suburb - Sharjah - United Arab Emirates)...
#
# 🔍 Searching: Mosques in Dubai
# Fetching reviews for Al Farooq Omar Bin Al Khattab Mosque (119 6D St - Al Safa - Al Safa 1 - Dubai - United Arab Emirates)...
# Fetching reviews for Reserve Beach (Praia da Reserva - Av. Lúcio Costa - Barra da Tijuca, Rio de Janeiro - RJ, 22620-172, Brazil)...
#
# 🔍 Searching: Live music in Rio de Janeiro
# Fetching reviews for Rio Scenarium (R. do Lavradio, 20 - Centro, Rio de Janeiro - RJ, 20230-070, Brazil)...
# Fetching reviews for Bar Carioca da Gema (Av. Mem de Sá, 79 - Lapa, Rio de Janeiro - RJ, 20230-150, Brazil)...
# Fetching reviews for Beco das Garrafas (Rua Duvivier, 37 - Lojas J, K, L - Copacabana, Rio de Janeiro - RJ, 22020-020, Brazil)...
#
# 🔍 Searching: Street markets in Rio de Janeiro
# Fetching reviews for Feira Hippie de Ipanema (Praça General Osório - Ipanema, Rio de Janeiro - RJ, 22410-020, Brazil)...
# Fetching reviews for Mercado Popular Uruguaiana (Metro - R. Uruguaiana - Centro, Rio de Janeiro - RJ, 20070-006, Brazil)...
# Fetching reviews for Mercadão Madureira (Av. Min. Edgard Romero, 239 - Madureira, Rio de Janeiro - RJ, 21360-201, Brazil)...
#
# 🔍 Searching: Historic landmarks in Rio de Janeiro
# Fetching reviews for Copacabana Fort (Army History Museum and Copacabana Fort) (Praça Cel. Eugênio Franco, 1, Posto 6 - Copacabana, Rio de Janeiro - RJ, 22070-020, Brazil)...
# Fetching reviews for Pedra do Sal (R. Tia Ciata - Saúde, Rio de Janeiro - RJ, 20081-040, Brazil)...
# Fetching reviews for Escadaria Selarón (R. Manuel Carneiro - Santa Teresa, Rio de Janeiro - RJ, 20241-120, Brazil)...
#
# 🔍 Searching: Cable car in Rio de Janeiro
# Fetching reviews for Sugar Loaf cable car (Av. Pasteur, 520 - Urca, Rio de Janeiro - RJ, 22290-240, Brazil)...
#
# 🔍 Searching: UNESCO heritage site in Petra
# Fetching reviews for Petra (Jordan)...
# Fetching reviews for Great Temple (8CHR+FV3, Wadi Musa, Jordan)...
# Fetching reviews for Petra Archaeological Park (8FH9+3HG, Wadi Musa, Jordan)...
#
# 🔍 Searching: Canyon hiking in Petra
# Fetching reviews for Petra (Jordan)...
#
# 🔍 Searching: Archaeology in Petra
# Fetching reviews for Petra Archaeological Park (8FH9+3HG, Wadi Musa, Jordan)...
# Fetching reviews for Petra (Jordan)...
# Fetching reviews for Royal Tombs (Wadi Musa, Jordan)...
#
# 🔍 Searching: Desert trekking in Petra
# Fetching reviews for Petra (Jordan)...
#
# 🔍 Searching: Stargazing in Petra
# Fetching reviews for RumSky Stargazing Adventure (Wadi Rum - Disi Street Aqaba, Jordan)...
#
# 🔍 Searching: Skiing in Queenstown
# Fetching reviews for Coronet Peak (Queenstown 9371, New Zealand)...
# Fetching reviews for The Remarkables Ski Area (Queenstown 9300, New Zealand)...
# Fetching reviews for Cardrona Alpine Resort (Cardrona Valley Rd, Cardrona 9305, New Zealand)...
#
# 🔍 Searching: Snowboarding in Queenstown
# Fetching reviews for Coronet Peak (Queenstown 9371, New Zealand)...
# Fetching reviews for The Remarkables Ski Area (Queenstown 9300, New Zealand)...
# Fetching reviews for Cardrona Alpine Resort (Cardrona Valley Rd, Cardrona 9305, New Zealand)...
#
# 🔍 Searching: Bungee jumping in Queenstown
# Fetching reviews for AJ Hackett Ledge Bungy & Swing (Brecon Street, Queenstown 9300, New Zealand)...
# Fetching reviews for AJ Hackett Bungy - Queenstown Bungy Centre (Shotover &, Camp Street, Queenstown 9300, New Zealand)...
# Fetching reviews for Shotover Canyon Swing (34 Shotover Street, Queenstown 9300, New Zealand)...
#
# 🔍 Searching: Wine tasting in Queenstown
# Fetching reviews for Queenstown Wine Trail Wine Tours, Queenstown, New Zealand (160 Gorge Road, Queenstown 9300, New Zealand)...
# Fetching reviews for The Winery - Queenstown (9 Ballarat Street, The Mall, Queenstown 9300, New Zealand)...
# Fetching reviews for Appellation Wine Tours, Queenstown, New Zealand (33 Brookes Road, Frankton, Queenstown 9300, New Zealand)...
#
# 🔍 Searching: Lake cruises in Queenstown
# Fetching reviews for Million Dollar Queenstown Cruise (50 Beach Street, Queenstown 9300, New Zealand)...
# Fetching reviews for RealNZ | TSS Earnslaw Queenstown Cruise (Steamer Wharf, Beach Street, Queenstown 9300, New Zealand)...
# Fetching reviews for TSS Earnslaw Pop Pop Boats - c/o Real Journeys (88 Beach Street, City, Queenstown 9300, New Zealand)...
#                   query                     place_id          place_name  \
# 0  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 1  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 2  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 3  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 4  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
#
#                           place_address  rating  \
# 0  350, 356 Old St, London EC1V 9NQ, UK       5
# 1  350, 356 Old St, London EC1V 9NQ, UK       5
# 2  350, 356 Old St, London EC1V 9NQ, UK       5
# 3  350, 356 Old St, London EC1V 9NQ, UK       5
# 4  350, 356 Old St, London EC1V 9NQ, UK       5
#
#                                                 text                   author  \
# 0  {'text': 'Great vibe, live music, and amazing ...         Natasha Williams
# 1  {'text': 'Old street record offers a fantastic...         Shahnawaz Faiyaz
# 2  {'text': 'I had a great time here  the ambianc...                 N Mendes
# 3  {'text': 'I recently visited OLD STREET RECORD...  ABDELLATIF EL GHAZOUANI
# 4  {'text': 'Went here last night with my friends...           Marina Garrido
#
#                       publishTime
# 0  2025-08-06T19:58:26.853273660Z
# 1  2025-07-23T20:19:31.875988720Z
# 2  2025-06-30T20:36:32.568566035Z
# 3  2025-07-23T20:03:13.379092229Z
# 4  2025-07-05T08:20:39.322927154Z
#
# ✅ Total reviews collected: 667

# %%
df.head(10)
# Out:
#                   query                     place_id          place_name  \
# 0  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 1  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 2  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 3  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 4  Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo  Old Street Records
# 5  Live music in London  ChIJ8zv5aLAcdkgRondZx7cngr0   The Old Blue Last
# 6  Live music in London  ChIJ8zv5aLAcdkgRondZx7cngr0   The Old Blue Last
# 7  Live music in London  ChIJ8zv5aLAcdkgRondZx7cngr0   The Old Blue Last
# 8  Live music in London  ChIJ8zv5aLAcdkgRondZx7cngr0   The Old Blue Last
# 9  Live music in London  ChIJ8zv5aLAcdkgRondZx7cngr0   The Old Blue Last
#
#                               place_address  rating  \
# 0      350, 356 Old St, London EC1V 9NQ, UK       5
# 1      350, 356 Old St, London EC1V 9NQ, UK       5
# 2      350, 356 Old St, London EC1V 9NQ, UK       5
# 3      350, 356 Old St, London EC1V 9NQ, UK       5
# 4      350, 356 Old St, London EC1V 9NQ, UK       5
# 5  38 Great Eastern St, London EC2A 3ES, UK       5
# 6  38 Great Eastern St, London EC2A 3ES, UK       5
# 7  38 Great Eastern St, London EC2A 3ES, UK       4
# 8  38 Great Eastern St, London EC2A 3ES, UK       4
# 9  38 Great Eastern St, London EC2A 3ES, UK       5
#
#                                                 text                   author  \
# 0  {'text': 'Great vibe, live music, and amazing ...         Natasha Williams
# 1  {'text': 'Old street record offers a fantastic...         Shahnawaz Faiyaz
# 2  {'text': 'I had a great time here  the ambianc...                 N Mendes
# 3  {'text': 'I recently visited OLD STREET RECORD...  ABDELLATIF EL GHAZOUANI
# 4  {'text': 'Went here last night with my friends...           Marina Garrido
# 5  {'text': 'Had a really great night at this pub...                   Celina
# 6  {'text': 'We went for the Friday jazz night. T...                 Skylar B
# 7  {'text': 'Everything's big at the Old Blue Las...           Peter Le Riche
# 8  {'text': 'Hard to review because it’s an old E...          Darren A. Smith
# 9  {'text': 'Super busy on a Saturday night so we...                 Pepper W
#
#                       publishTime
# 0  2025-08-06T19:58:26.853273660Z
# 1  2025-07-23T20:19:31.875988720Z
# 2  2025-06-30T20:36:32.568566035Z
# 3  2025-07-23T20:03:13.379092229Z
# 4  2025-07-05T08:20:39.322927154Z
# 5     2025-02-17T20:41:23.952489Z
# 6     2024-11-16T18:29:21.403558Z
# 7     2025-03-10T07:30:14.084446Z
# 8  2025-07-09T19:55:15.962507137Z
# 9     2025-03-11T15:40:54.069554Z

# %%
import ast

def get_review_text(x):
    if isinstance(x, dict):
        return x.get('text', '')
    elif isinstance(x, str):
        try:
            d = ast.literal_eval(x)
            if isinstance(d, dict) and 'text' in d:
                return d['text']
            else:
                return x
        except Exception:
            return x
    else:
        return ''

# %%
df['reviews'] = df['text'].apply(get_review_text)
df = df.drop(columns=['text'])
df
# Out:
#                           query                     place_id  \
# 0          Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo
# 1          Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo
# 2          Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo
# 3          Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo
# 4          Live music in London  ChIJRxL62ywddkgRVOCT1wvnzIo
# ..                          ...                          ...
# 662  Lake cruises in Queenstown  ChIJQaRNqoEd1akRfAHRghuf0iE
# 663  Lake cruises in Queenstown  ChIJQaRNqoEd1akRfAHRghuf0iE
# 664  Lake cruises in Queenstown  ChIJQaRNqoEd1akRfAHRghuf0iE
# 665  Lake cruises in Queenstown  ChIJQaRNqoEd1akRfAHRghuf0iE
# 666  Lake cruises in Queenstown  ChIJQaRNqoEd1akRfAHRghuf0iE
#
#                                          place_name  \
# 0                                Old Street Records
# 1                                Old Street Records
# 2                                Old Street Records
# 3                                Old Street Records
# 4                                Old Street Records
# ..                                              ...
# 662  TSS Earnslaw Pop Pop Boats - c/o Real Journeys
# 663  TSS Earnslaw Pop Pop Boats - c/o Real Journeys
# 664  TSS Earnslaw Pop Pop Boats - c/o Real Journeys
# 665  TSS Earnslaw Pop Pop Boats - c/o Real Journeys
# 666  TSS Earnslaw Pop Pop Boats - c/o Real Journeys
#
#                                          place_address  rating  \
# 0                 350, 356 Old St, London EC1V 9NQ, UK       5
# 1                 350, 356 Old St, London EC1V 9NQ, UK       5
# 2                 350, 356 Old St, London EC1V 9NQ, UK       5
# 3                 350, 356 Old St, London EC1V 9NQ, UK       5
# 4                 350, 356 Old St, London EC1V 9NQ, UK       5
# ..                                                 ...     ...
# 662  88 Beach Street, City, Queenstown 9300, New Ze...       5
# 663  88 Beach Street, City, Queenstown 9300, New Ze...       5
# 664  88 Beach Street, City, Queenstown 9300, New Ze...       5
# 665  88 Beach Street, City, Queenstown 9300, New Ze...       5
# 666  88 Beach Street, City, Queenstown 9300, New Ze...       5
#
#                       author                     publishTime  \
# 0           Natasha Williams  2025-08-06T19:58:26.853273660Z
# 1           Shahnawaz Faiyaz  2025-07-23T20:19:31.875988720Z
# 2                   N Mendes  2025-06-30T20:36:32.568566035Z
# 3    ABDELLATIF EL GHAZOUANI  2025-07-23T20:03:13.379092229Z
# 4             Marina Garrido  2025-07-05T08:20:39.322927154Z
# ..                       ...                             ...
# 662                    C Pal     2023-08-05T04:13:45.175618Z
# 663                 Ozzie Oz     2024-09-25T03:22:15.858827Z
# 664          Culinary Palate     2024-01-14T16:57:50.686778Z
# 665               Brad Tynan     2024-05-18T07:20:52.220468Z
# 666                  Trentyz     2022-03-06T04:04:28.166902Z
#
#                                                reviews
# 0    Great vibe, live music, and amazing deals!\nHa...
# 1    Old street record offers a fantastic dining ex...
# 2    I had a great time here  the ambiance is super...
# 3    I recently visited OLD STREET RECORD  and had ...
# 4    Went here last night with my friends and it wa...
# ..                                                 ...
# 662  It was like traveling back in time, I'm glad m...
# 663  We took the 1.30pm boat cruise across to the f...
# 664  Traveling on a steamboat is something not many...
# 665  Loved it. The boat is to a absolutely worth it...
# 666  Only coal steamboat in the Southern Hemisphere...
#
# [667 rows x 8 columns]

# %%
df.to_csv("sample_location_activity_reviews.csv", index=False)

# %%
import requests
import pandas as pd

API_KEY = "AIzaSyCmtDpxywkZEnOlM7GPsOJhxdpUUeol9aM"
QUERY = "London nightlife"
TOP_N = 3

# Step 1: Search for surfing beaches
search_url = "https://places.googleapis.com/v1/places:searchText"

search_headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "places.id,places.displayName,places.formattedAddress"
}

search_body = {
    "textQuery": QUERY
}

search_response = requests.post(search_url, headers=search_headers, json=search_body).json()

if "places" not in search_response:
    raise ValueError(f"No places found for query '{QUERY}'")

# Step 2: Take top N places
places = search_response["places"][:TOP_N]

all_reviews = []

# Step 3: Loop through places and fetch reviews
for place in places:
    place_id = place["id"]
    place_name = place["displayName"]["text"]
    place_address = place.get("formattedAddress", "")

    print(f"Fetching reviews for {place_name} ({place_address})...")

    details_url = f"https://places.googleapis.com/v1/places/{place_id}"
    details_headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": "id,displayName,reviews"
    }

    details_response = requests.get(details_url, headers=details_headers).json()

    reviews = details_response.get("reviews", [])
    for r in reviews:
        all_reviews.append({
            "place_id": place_id,
            "place_name": place_name,
            "place_address": place_address,
            "rating": r.get("rating"),
            "text": r.get("text"),
            "author": r.get("authorAttribution", {}).get("displayName"),
            "publishTime": r.get("publishTime")
        })

# Step 4: Save to DataFrame
df = pd.DataFrame(all_reviews)
print(df.head())
print(f"\nTotal reviews collected: {len(df)}")

# Optional: Save to CSV
df.to_csv("surfing_beach_reviews.csv", index=False)
